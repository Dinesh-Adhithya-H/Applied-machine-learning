# %% [markdown]
# ## Linear models for classification : Binary classification

# %% [markdown]
# ### Logistic regression

# %% [markdown]
# #### Logistic regression for binary classification on fruits dataset using height, width features (positive class: apple, negative class: others)

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data=pd.read_csv("fruit_data_with_colors.txt",delimiter="\t")

# %%
data.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
apple_data=data.loc[data["fruit_name"]=="apple"]

# %%
not_apple_data=data.loc[data["fruit_name"]!="apple"]

# %%
not_apple_data=np.array(not_apple_data[["mass","width","height","color_score"]])
apple_data=np.array(apple_data[["mass","width","height","color_score"]])

# %%
plt.figure()
plt.scatter(apple_data["width"],apple_data["height"],label="apple")
plt.scatter(not_apple_data["width"],not_apple_data["height"],label="not apple")
plt.xlabel("width")
plt.ylabel("height")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from pandas.plotting import scatter_matrix
x1=data[["height","width","mass","color_score"]]
x_train,x_test,y_train,y_test=train_test_split(x1,y,random_state=69)
cmap=cm.get_cmap("gnuplot")
scatter=scatter_matrix(x_train,c=y_train,alpha=0.5,marker= "o",hist_kwds={"bins":15}, figsize=(9,9), cmap=cmap)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
y=[1 for i in range(len(apple_data))]

# %%
y=y+[0 for i in range(len(not_apple_data))]

# %%
x=[]
for i in apple_data :
    x.append(i)
for i in not_apple_data :
    x.append(i)

# %%
y=np.array(y)
x=np.array(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=69)

# %%
clf=LogisticRegression().fit(x_train,y_train)

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(clf,x_test,y_test)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(clf.score(x_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(clf.score(x_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.78
# Accuracy of Logistic regression classifier on test set: 0.72
